# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !zip -r /content/traindata.zip /content/gdrive/MyDrive/NLP/github/NLP_Project/models
from google.colab import files
files.download("/content/traindata.zip")

# %% [markdown]
# #Train Data

# %%
import pandas as pd
import csv
import torch
from collections import defaultdict
import matplotlib.pyplot as plt
import os
import ast
import numpy as np
import nltk
import pickle

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
PATH = 'gdrive/MyDrive/NLP/github/'

# %%
def save_data(data_arr,columns_arr,directory):
  df = pd.DataFrame(data_arr, columns=columns_arr)
  df.to_csv(directory, index=False, quoting=csv.QUOTE_ALL)

# %%
# !pip install langdetect

# %%
from langdetect import detect

def is_english(text):
  try:
      return detect(text) == 'en'
  except:
      return False

# %%
categories = ['action','adventure','rpg','strategy','simulation','sports_and_racing']
all_data = []
directory = '/content/gdrive/MyDrive/NLP/github/data/traindata/'
for category in categories:
  count = 0
  df = pd.read_csv(f'gdrive/MyDrive/NLP/github/data/clean/{category}/{category}.csv')
  data = df.to_dict('dict')
  category_data =  []
  for idx in range(len(data['id'])):
      id = data['id'][idx]
      about = data['clean_description'][idx]
      if("About This Content" in about):
        about = about[:about.index("About This Content")]
      if(len(about)<400) and is_english(about):
        all_data.append([id,about,category])
        category_data.append([id,about])
        count+=1
  save_data(category_data,['id','about'],f'{directory}{category}.csv')
  print(f"{category}: {count}")

save_data(all_data,['id','about','label'],f'{directory}all.csv')
# Out:
# action: 507
# adventure: 497
# rpg: 314
# strategy: 391
# simulation: 520
# sports_and_racing: 458

# %%
# !zip -r /content/traindata.zip /content/gdrive/MyDrive/NLP/github/data/traindata/
from google.colab import files
files.download("/content/traindata.zip")
# Out:
# updating: content/gdrive/MyDrive/NLP/github/data/traindata/ (stored 0%)
# updating: content/gdrive/MyDrive/NLP/github/data/traindata/action.csv (deflated 60%)
# updating: content/gdrive/MyDrive/NLP/github/data/traindata/adventure.csv (deflated 60%)
# updating: content/gdrive/MyDrive/NLP/github/data/traindata/rpg.csv (deflated 59%)
# updating: content/gdrive/MyDrive/NLP/github/data/traindata/strategy.csv (deflated 61%)
# updating: content/gdrive/MyDrive/NLP/github/data/traindata/simulation.csv (deflated 61%)
# updating: content/gdrive/MyDrive/NLP/github/data/traindata/sports_and_racing.csv (deflated 61%)
# updating: content/gdrive/MyDrive/NLP/github/data/traindata/all.csv (deflated 62%)

# %%
TOKEN = ""

# %% [markdown]
# #Github First Clone

# %%
import os
os.mkdir('/content/gdrive/MyDrive/NLP/github')

# %%
# !git clone https://bavanDA:$TOKEN@github.com/bavanDA/NLP_Project.git
# !cd NLP_Project && git checkout word2vec
# !cp -R  /content/NLP_Project /content/gdrive/MyDrive/NLP/github/
# Out:
# Cloning into 'NLP_Project'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 168 (delta 14), reused 68 (delta 8), pack-reused 86
# Receiving objects: 100% (168/168), 121.06 MiB | 13.17 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# Updating files: 100% (35/35), done.
# /bin/bash: get: command not found

# %%
# !python -m src.word2vector.run $1
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# iter 10: 15.554223
# iter 20: 15.455103
# iter 30: 15.521055
# iter 40: 15.469340
# iter 50: 15.359217
# iter 60: 15.338465
# iter 70: 15.288256
# iter 80: 15.271054
# iter 90: 15.239463
# iter 100: 15.217075
# iter 110: 15.279678
# iter 120: 15.262903
# iter 130: 15.362035
# iter 140: 15.417384
# iter 150: 15.370854
# iter 160: 15.441015
# iter 170: 15.385676
# iter 180: 15.409350
# iter 190: 15.447099
# iter 200: 15.406715
# iter 210: 15.397453
# iter 220: 15.367169
# iter 230: 15.300275
# iter 240: 15.290096
# iter 250: 15.196563
# iter 260: 15.161077
# iter 270: 15.104490
# iter 280: 15.126967
# iter 290: 15.133077
# iter 300: 15.192265
# iter 310: 15.179862
# iter 320: 15.259569
# iter 330: 15.220924
# iter 340: 15.359579
# iter 350: 15.392172
# iter 360: 15.430782
# iter 370: 15.398830
# iter 380: 15.315100
# iter 390: 15.288933
# iter 400: 15.340309
# ...

# %%
# %cd gdrive/MyDrive/NLP/github/NLP_Project

# %%
category_dict = {'action':set(),'adventure':set(),'rpg':set(),'strategy':set(),'simulation':set(),'sports_and_racing':set()}
categories = ['action','adventure','rpg','strategy','simulation','sports_and_racing']

for category in categories:
  df = pd.read_csv(f'data/traindata/{category}.csv')
  data = df.to_dict('dict')
  for about in data['about'].values():
      for sentence in nltk.sent_tokenize(about):
                splitted = sentence.strip().split()[1:]
                # Deal with some peculiar encoding issues with this file
                words = [w.lower() for w in splitted]
      for word in words:
          category_dict[category].add(word)

# %%
common_words = set()

for word in category_dict['action']:
  count = 0
  for category in categories:
    if word in category_dict[category]:
      count+=1
  if(count==6):
    common_words.add(word)

# %%
len(common_words)
# Out:
# 361

# %%
def cosine_similarity(x, y):
    return np.dot(x, y) / (np.linalg.norm(x) * np.linalg.norm(y))

# %%
def load_saved_params(category):
    """
    A helper function that loads previously saved parameters and resets
    iteration start.
    """
    params_file = f"models/{category}.word2vec.npy"
    params = np.load(params_file)
    return params

# %%
sim_result = []
for word in common_words:
  for i in range(6):
    for j in range(i+1,6):
      cat1 , cat2 = categories[i],categories[j]
      params1,params2 = load_saved_params(cat1),load_saved_params(cat2)
      dataset1,dataset2 = SteamData(f'data/traindata/{cat1}.csv'), SteamData(f'data/traindata/{cat2}.csv')
      idx1 , idx2 = dataset1.tokens()[word], dataset2.tokens()[word]
      res =cosine_similarity(params1[idx1],params2[idx2])
      sim_result.append([word,cat1,cat2,res])

save_data(sim_result,['word','category1','category2','cosine similarity'],f'stats/cosine_similarity.csv')
# Out:
# Streaming output truncated to the last 5000 lines.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
from src.word2vector.treebank import *

params = load_saved_params('action')
dataset = SteamData(f'data/traindata/action.csv')
tokens = dataset.tokens()
action_index = tokens['action']
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
action_index
# Out:
# 194

# %%
print(params[action_index ])
# Out:
# [ 0.20318634  0.14354444  0.03348119  0.17039878 -0.23330821  0.69115018
#   0.76097371 -0.40537318  0.47286932  0.12095595]

# %% [markdown]
# #Github pull and push

# %%
# %cd gdrive/MyDrive/NLP/github/NLP_Project
# Out:
# [Errno 2] No such file or directory: 'gdrive/MyDrive/NLP/github/NLP_Project'
# /content/gdrive/MyDrive/NLP/github/NLP_Project

# %%
# !git stash
# !git pull
# Out:
# Saved working directory and index state WIP on word2vec: 0eab328 add traindata
# Updating 0eab328..b625121
# Fast-forward
#  action.word2vec.npy                                  | Bin 0 -> 913248 bytes
#  adventure.word2vec.npy                               | Bin 0 -> 911008 bytes
#  logs/word2vec                                        |   1 +
#  rpg.word2vec.npy                                     | Bin 0 -> 666368 bytes
#  simulation.word2vec.npy                              | Bin 0 -> 914208 bytes
#  sports_and_racing.word2vec.npy                       | Bin 0 -> 783168 bytes
#  src/__pycache__/config.cpython-310.pyc               | Bin 390 -> 434 bytes
#  src/config.py                                        |   1 +
#  src/logger/__pycache__/logger.cpython-310.pyc        | Bin 607 -> 626 bytes
#  src/word2vector/__pycache__/run.cpython-310.pyc      | Bin 1113 -> 1237 bytes
#  src/word2vector/__pycache__/sgd.cpython-310.pyc      | Bin 2764 -> 2782 bytes
# ...

# %%
# %cd models
# Out:
# /content/gdrive/MyDrive/NLP/github/NLP_Project/models

# %%
# !git add .

# %%
# !git config --global user.email "bavan1379@gmail.com"
# !git config --global user.name "bavan"

# %%
# !git commit -m "add word2vec"
# !git push
# Out:
# [word2vec fe49b16] add word2vec
#  54 files changed, 2753559 insertions(+), 1 deletion(-)
#  create mode 100644 github/data/clean/action/action.csv
#  create mode 100644 github/data/clean/adventure/adventure.csv
#  create mode 100644 github/data/clean/rpg/rpg.csv
#  create mode 100644 github/data/clean/simulation/simulation.csv
#  create mode 100644 github/data/clean/sports_and_racing/sports_and_racing.csv
#  create mode 100644 github/data/clean/strategy/strategy.csv
#  create mode 100644 github/data/raw/action/action.csv
#  create mode 100644 github/data/raw/adventure/adventure.csv
#  create mode 100644 github/data/raw/rpg/rpg.csv
#  create mode 100644 github/data/raw/simulation/simulation.csv
#  create mode 100644 github/data/raw/sports_and_racing/sports_and_racing.csv
#  create mode 100644 github/data/raw/strategy/strategy.csv
#  create mode 100644 github/data/sentencebroken/action/action.csv
#  create mode 100644 github/data/sentencebroken/adventure/adventure.csv
# ...

# %%
# !git pull -v
# Out:
# From https://github.com/bavanDA/NLP_Project
#  = [up to date]      word2vec   -> origin/word2vec
#  = [up to date]      main       -> origin/main
# Already up to date.

# %%
# !git remote set-url origin https://:$TOKEN@github.com/bavanDA/NLP_Project.git

# %%
# !git remote -v
# Out:
# origin	https://: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@github.com/bavanDA/NLP_Project.git (fetch)
# origin	https://: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@github.com/bavanDA/NLP_Project.git (push)

# %%
# !git push
# Out:
# remote: No anonymous write access.
# fatal: Authentication failed for 'https://github.com/bavanDA/NLP_Project.git/'

# %%
# %cd content
# Out:
# /content

# %%
files.download("/content/models.zip")

# %%
# !zip -r /content/logss.zip /content/gdrive/MyDrive/NLP/github/NLP_Project/logs
from google.colab import files
files.download("/content/logss.zip")
# Out:
# updating: content/gdrive/MyDrive/NLP/github/NLP_Project/logs/ (stored 0%)
# updating: content/gdrive/MyDrive/NLP/github/NLP_Project/logs/.ipynb_checkpoints/ (stored 0%)
# updating: content/gdrive/MyDrive/NLP/github/NLP_Project/logs/language_model: action (stored 0%)
# updating: content/gdrive/MyDrive/NLP/github/NLP_Project/logs/language_model: adventure (stored 0%)
# updating: content/gdrive/MyDrive/NLP/github/NLP_Project/logs/language_model: rpg (stored 0%)
# updating: content/gdrive/MyDrive/NLP/github/NLP_Project/logs/language_model: strategy (stored 0%)
# updating: content/gdrive/MyDrive/NLP/github/NLP_Project/logs/language_model: simulation (stored 0%)
# updating: content/gdrive/MyDrive/NLP/github/NLP_Project/logs/word2vec (deflated 65%)
# updating: content/gdrive/MyDrive/NLP/github/NLP_Project/logs/language_model: sports_and_racing (stored 0%)

# %%
# !zip -r /content/models.zip /content/gdrive/MyDrive/NLP/github/data/models
from google.colab import files
files.download("/content/models.zip")
